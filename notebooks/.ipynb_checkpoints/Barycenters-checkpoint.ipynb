# %%
using PyPlot,JLD
include("../src/barycenters.jl")
# Out:
# WARNING: Method definition div0(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:14 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:14.
# WARNING: replacing docs for 'div0 :: Tuple{Any,Any}' in module 'Main'.
# WARNING: Method definition proxdivOT!(Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:23 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:23.
# WARNING: Method definition proxdivKL!(Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:24 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:24.
# WARNING: Method definition baryOT!(Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:26 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:26.
# WARNING: Method definition baryKL!(Any, Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:27 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:27.
# WARNING: Method definition proxdivbaryOT!(Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:30 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:30.
# WARNING: Method definition proxdivbaryKL!(Any, Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:35 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:35.
# WARNING: Base.SparseMatrix is deprecated, use Base.SparseArrays instead.
#   likely near /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:480
# WARNING: Method definition computekernel!(Base.SparseArrays.SparseMatrixCSC, AbstractArray, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:41 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:41.
# WARNING: replacing docs for 'computekernel! :: Tuple{SparseMatrixCSC,AbstractArray,Any,Any,Any}' in module 'Main'.
# WARNING: Base.SparseMatrix is deprecated, use Base.SparseArrays instead.
#   likely near /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:52
# WARNING: Method definition truncatekernel!(Base.SparseArrays.SparseMatrixCSC, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:53 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:53.
# WARNING: Method definition kernelinit(Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:67 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:67.
# WARNING: replacing docs for 'kernelinit :: Tuple{Any,Any,Any}' in module 'Main'.
# WARNING: Method definition coordvect(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:79 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:79.
# WARNING: replacing docs for 'coordvect :: Tuple{Any,Any}' in module 'Main'.
# WARNING: Method definition coarser(Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:91 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:91.
# WARNING: Method definition finer(Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:92 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:92.
# WARNING: Method definition finerplan(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:93 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:93.
# WARNING: Method definition coarser1d(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:96 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:96.
# WARNING: Method definition coarser2d(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:106 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:106.
# WARNING: Method definition finer1d(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:121 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:121.
# WARNING: Method definition finer2d(Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:131 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:131.
# WARNING: Method definition finerplan1d(Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:147 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:147.
# WARNING: Method definition finerplan2d(Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:162 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:162.
# WARNING: Method definition scalingiter(Any, Any, Any, Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:197 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:197.
# WARNING: replacing docs for 'scalingiter :: Tuple{Any,Any,Any,Any,Any,Any,Any,Any,Any,Any}' in module 'Main'.
# WARNING: Method definition barycenter(Any, Any, Any, Any, Any) in module Main at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:241 overwritten at /Users/chizat/Documents/Code/optimal-transport/src/barycenters.jl:241.
# WARNING: Method definition #barycenter(Array{Any, 1}, Main.#barycenter, Any, Any, Any, Any, Any) in module Main overwritten.
# barycenter (generic function with 1 method)

# %%
S = 3 # number of marginals
N1,N2 = 512,512 # discretization of the domain

p = fill(zeros(N1,N2),S)
X1, X2 = linspace(0,1,N1), linspace(0,1,N2)#plus .2; times .3 donut .05 trio .12
fplus(x1,x2,p1,p2,s) = ((-.09*s<x1-p1<.09*s)&&(-.45*s<x2-p2<.45*s))||((-.45*s<x1-p1<.45*s)&&(-.09*s<x2-p2<.09*s))
ftimes(x1,x2,p1,p2,s)= ((-.07*s<x2+x1-p1-p2<.07*s)&&(-.4*s<x1-x2-p1+p2<.4*s))||((-.4*s<x2+x1-p1-p2<.4*s)&&(-.07*s<x1-x2-p1+p2<.07*s))
fdonut(x1,x2,p1,p2,s)= (.65*s < norm([x1-p1,x2-p2]) < s)
ftrio(x1,x2,p1,p2,s) = (norm([x1-p1-s/2,x2-p2-s/2]) < s/4)||(norm([x1-p1+s/2,x2-p2-s/2]) < s/4)||(norm([x1-p1,x2-p2+s/2]) < s/4)
fduo(x1,x2,p1,p2,s)  = (norm([x1-p1-s/2,x2-p2-s/2]) < s/3)||(norm([x1-p1+s/2,x2-p2+s/2]) < s/3)
fsquare(x1,x2,p1,p2,s)=(-s/3<x1-p1<s/3)&&(-s/3<x2-p2<s/3)
fH(x1,x2,p1,p2,s)= ((-.4*s<x2-p2<-.2*s)&&(-.45*s<x1-p1<.45*s))||((.2*s<x2-p2<.4*s)&&(-.45*s<x1-p1<.45*s))||((-.2*s<x2-p2<.2*s)&&(-.1*s<x1-p1<.1*s))
fQ(x1,x2,p1,p2,s)= (.65*s < norm([x1-p1,x2-p2]) < s)||((-.3*s<x2+x1-p1-p2<.3*s)&&(-2.*s<x1-x2-p1+p2<-.3*s))

p[1] = Float64[fH(x1,x2,0.2,0.85,.28) + ftimes(x1,x2,0.82,0.5,.75) + fplus(x1,x2,0.2,0.15,.3) for x1 in X1, x2 in X2]
p[2] = Float64[fQ(x1,x2,0.2,0.8,.16) + ftrio(x1,x2,0.82,0.5,.23) + fdonut(x1,x2,0.2,0.15,.13) for x1 in X1, x2 in X2]
p[3] = Float64[fdonut(x1,x2,0.2,0.85,.15) + fsquare(x1,x2,0.82,0.5,.29) + fduo(x1,x2,0.2,0.2,.22) for x1 in X1, x2 in X2]

# rescale or don't
for s=1:S;   p[s]= p[s]/sum(p[s]);end
vm = maximum([maximum(p[1]);maximum(p[2]);maximum(p[3])])

figure(figsize=[10,3]);
subplot(131); pcolormesh(p[1],cmap="afmhot_r",vmax=vm,vmin=0); axis("off");
subplot(132); pcolormesh(p[2],cmap="afmhot_r",vmax=vm,vmin=0); axis("off");
subplot(133); pcolormesh(p[3],cmap="afmhot_r",vmax=vm,vmin=0); axis("off");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x321026f50>)
# WARNING: Method definition fplus(Any, Any, Any, Any, Any) in module Main at In[96]:6 overwritten at In[119]:6.
# WARNING: Method definition ftimes(Any, Any, Any, Any, Any) in module Main at In[96]:7 overwritten at In[119]:7.
# WARNING: Method definition fdonut(Any, Any, Any, Any, Any) in module Main at In[96]:8 overwritten at In[119]:8.
# WARNING: Method definition ftrio(Any, Any, Any, Any, Any) in module Main at In[96]:9 overwritten at In[119]:9.
# WARNING: Method definition fduo(Any, Any, Any, Any, Any) in module Main at In[96]:10 overwritten at In[119]:10.
# WARNING: Method definition fsquare(Any, Any, Any, Any, Any) in module Main at In[96]:11 overwritten at In[119]:11.
# WARNING: Method definition fH(Any, Any, Any, Any, Any) in module Main at In[96]:12 overwritten at In[119]:12.
# WARNING: Method definition fQ(Any, Any, Any, Any, Any) in module Main at In[96]:13 overwritten at In[119]:13.

# %%
#save("../output/barycenters/marginals.jld","m1",p[1],"m2",p[2],"m3",p[3])

# %%
## ϵ = 1e-5
α0 = ([1;3;0], [0;3;1], [2;2;0], [1;2;1],[0;2;2],[3;1;0],[2;1;1],[1;1;2],[0;1;3],[3;0;1],[2;0;2],[1;0;3],[1;1;1])
λ = Inf
for i=1:length(α0)
    @show α0[i]
    p0 = cat(2,p[1][:],p[2][:],p[3][:])
    α = [α0[i][1];α0[i][2];α0[i][3]]
    if α0[i][3]==0
        p0=cat(2,p[1][:],p[2][:])
        α = [α[1];α[2]]
    elseif α0[i][2]==0
        p0=cat(2,p[1][:],p[3][:])
        α = [α[1];α[3]]
    elseif α0[i][1]==0
        p0=cat(2,p[2][:],p[3][:])
        α = [α[2];α[3]]
    end
    #@time h,K = barycenter(p0,λ,α/sum(α),2,ϵ; niter=300,epsstep=5., tol=0.);
    #bary = reshape(h,N1,N2)
    #pcolormesh(bary,cmap="bone_r");axis("off")
    #save("../output/barycenters/baryGHK$(α0[i][1])$(α0[i][2])$(α0[i][3]).jld","bary",bary)
end
p0 = cat(2,p[1][:],p[2][:])
#p0 = zeros(p0)
#p0[2:5,1] = 1;
#p0[end-10:end-1,2] = 1;
@time h,K = barycenter(p0,Inf,[1/4;3/4],2,1.0; niter=300,epsstep=5., tol=0.);
# Out:
# α0[i] = [1,3,0]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.630470 seconds (33.60 M allocations: 1.866 GB, 12.35% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   1.104804 seconds (6.82 M allocations: 477.629 MB, 6.69% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.135105 seconds (10.21 M allocations: 657.269 MB, 8.06% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.938465 seconds (6.82 M allocations: 477.629 MB, 6.75% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.167100 seconds (9.39 M allocations: 613.717 MB, 7.42% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   1.031062 seconds (5.04 M allocations: 383.164 MB, 5.46% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.502741 seconds (3.30 M allocations: 290.666 MB, 9.57% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.811584 seconds (21.49 M allocations: 1.499 GB, 7.77% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.871231 seconds (24.27 M allocations: 1.633 GB, 11.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.369109 seconds (16.19 M allocations: 1.241 GB, 7.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   3.071304 seconds (23.82 M allocations: 1.612 GB, 7.14% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.970113 seconds (14.05 M allocations: 1.137 GB, 5.12% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.926530 seconds (9.13 M allocations: 919.769 MB, 6.24% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.159206 seconds (4.05 M allocations: 667.151 MB, 7.92% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   6.145244 seconds (34.86 M allocations: 3.495 GB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.803873 seconds (30.92 M allocations: 3.306 GB, 7.85% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.920561 seconds (46.35 M allocations: 4.050 GB, 8.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   6.234993 seconds (30.92 M allocations: 3.306 GB, 7.67% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.892068 seconds (44.52 M allocations: 3.961 GB, 8.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   6.110569 seconds (22.45 M allocations: 2.898 GB, 6.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.210789 seconds (11.11 M allocations: 2.353 GB, 7.16% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  20.297718 seconds (101.97 M allocations: 12.175 GB, 8.11% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  18.621685 seconds (94.94 M allocations: 11.838 GB, 7.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  19.909110 seconds (142.39 M allocations: 14.124 GB, 7.90% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  17.970781 seconds (94.94 M allocations: 11.838 GB, 7.59% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  17.816039 seconds (94.94 M allocations: 11.838 GB, 7.00% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  17.943501 seconds (94.94 M allocations: 11.838 GB, 7.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  17.946127 seconds (94.94 M allocations: 11.837 GB, 7.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  18.496159 seconds (68.82 M allocations: 10.583 GB, 6.43% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 111.880731 seconds (681.16 M allocations: 61.822 GB, 19.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 108.727051 seconds (656.47 M allocations: 60.637 GB, 19.34% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 102.365859 seconds (656.47 M allocations: 60.637 GB, 19.42% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 103.124257 seconds (656.47 M allocations: 60.637 GB, 19.45% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 122.136208 seconds (652.32 M allocations: 60.438 GB, 16.21% gc time)
# 804.184819 seconds (4.87 G allocations: 445.181 GB, 14.97% gc time)
# α0[i] = [0,3,1]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.288416 seconds (33.60 M allocations: 1.866 GB, 13.09% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.784676 seconds (6.64 M allocations: 468.019 MB, 7.96% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   0.927495 seconds (9.94 M allocations: 642.855 MB, 9.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.839913 seconds (6.64 M allocations: 468.019 MB, 6.99% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.053777 seconds (9.09 M allocations: 597.651 MB, 7.46% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.885908 seconds (4.85 M allocations: 372.978 MB, 5.76% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.471502 seconds (3.18 M allocations: 284.462 MB, 8.08% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.652797 seconds (20.94 M allocations: 1.472 GB, 8.10% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.668715 seconds (24.06 M allocations: 1.624 GB, 11.47% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.131049 seconds (16.06 M allocations: 1.235 GB, 7.28% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   3.003657 seconds (23.60 M allocations: 1.602 GB, 6.99% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.892932 seconds (13.90 M allocations: 1.130 GB, 5.27% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.892925 seconds (9.03 M allocations: 914.878 MB, 6.10% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.261501 seconds (6.09 M allocations: 770.263 MB, 7.37% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   6.137693 seconds (34.27 M allocations: 3.468 GB, 7.88% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.809107 seconds (30.18 M allocations: 3.270 GB, 7.81% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.069681 seconds (45.24 M allocations: 3.997 GB, 8.68% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.623681 seconds (30.18 M allocations: 3.270 GB, 7.69% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.769478 seconds (43.51 M allocations: 3.914 GB, 8.38% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   6.142790 seconds (21.95 M allocations: 2.875 GB, 6.22% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.145383 seconds (13.95 M allocations: 2.492 GB, 7.63% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  18.393025 seconds (99.38 M allocations: 12.051 GB, 7.57% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  17.426634 seconds (92.28 M allocations: 11.710 GB, 6.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  19.256874 seconds (138.40 M allocations: 13.932 GB, 8.24% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  18.751338 seconds (92.28 M allocations: 11.710 GB, 7.41% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  19.030789 seconds (92.28 M allocations: 11.710 GB, 6.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  19.014540 seconds (92.28 M allocations: 11.710 GB, 7.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  18.096673 seconds (92.27 M allocations: 11.709 GB, 7.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  20.225844 seconds (87.37 M allocations: 11.482 GB, 6.79% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
#  99.143969 seconds (658.11 M allocations: 60.716 GB, 19.59% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
#  95.911710 seconds (632.69 M allocations: 59.495 GB, 19.93% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
#  95.024181 seconds (632.69 M allocations: 59.495 GB, 19.74% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 102.758745 seconds (632.69 M allocations: 59.495 GB, 19.78% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 125.588086 seconds (629.07 M allocations: 59.321 GB, 16.52% gc time)
# 768.381373 seconds (4.74 G allocations: 439.108 GB, 15.11% gc time)
# α0[i] = [2,2,0]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.342418 seconds (33.60 M allocations: 1.866 GB, 13.58% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.891553 seconds (6.82 M allocations: 477.629 MB, 7.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.042237 seconds (10.21 M allocations: 657.269 MB, 8.48% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.882043 seconds (6.82 M allocations: 477.629 MB, 7.37% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.067063 seconds (9.40 M allocations: 614.440 MB, 7.87% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.934106 seconds (5.05 M allocations: 383.761 MB, 5.86% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.489094 seconds (3.30 M allocations: 290.970 MB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.739172 seconds (21.52 M allocations: 1.500 GB, 7.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.765481 seconds (24.30 M allocations: 1.635 GB, 11.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.286876 seconds (16.22 M allocations: 1.242 GB, 7.22% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   3.070324 seconds (23.86 M allocations: 1.614 GB, 6.92% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.998116 seconds (14.07 M allocations: 1.138 GB, 5.02% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.945163 seconds (9.13 M allocations: 919.392 MB, 5.58% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.142404 seconds (4.05 M allocations: 667.073 MB, 6.47% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   6.530144 seconds (35.25 M allocations: 3.514 GB, 7.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   6.753040 seconds (31.27 M allocations: 3.322 GB, 7.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.915673 seconds (46.88 M allocations: 4.075 GB, 8.56% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   6.034531 seconds (31.27 M allocations: 3.322 GB, 7.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.882317 seconds (45.12 M allocations: 3.990 GB, 8.33% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   6.294365 seconds (22.88 M allocations: 2.919 GB, 6.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.384970 seconds (11.44 M allocations: 2.369 GB, 7.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  19.396720 seconds (105.59 M allocations: 12.349 GB, 7.52% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  18.892040 seconds (98.28 M allocations: 11.998 GB, 7.51% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  21.145478 seconds (147.40 M allocations: 14.364 GB, 7.90% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  19.866210 seconds (98.28 M allocations: 11.998 GB, 7.33% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  19.433587 seconds (98.28 M allocations: 11.998 GB, 7.00% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  19.551829 seconds (98.28 M allocations: 11.998 GB, 7.59% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  18.688049 seconds (98.28 M allocations: 11.998 GB, 7.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  19.269694 seconds (71.16 M allocations: 10.695 GB, 6.36% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 111.591497 seconds (702.55 M allocations: 62.849 GB, 18.79% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 108.453006 seconds (676.74 M allocations: 61.610 GB, 19.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 110.895572 seconds (676.74 M allocations: 61.610 GB, 18.92% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 116.349068 seconds (676.74 M allocations: 61.610 GB, 19.35% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 136.174618 seconds (672.69 M allocations: 61.416 GB, 16.56% gc time)
# 847.085438 seconds (5.01 G allocations: 451.824 GB, 14.90% gc time)
# α0[i] = [1,2,1]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   5.114761 seconds (50.39 M allocations: 2.796 GB, 11.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   1.280963 seconds (9.94 M allocations: 699.483 MB, 7.47% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.563119 seconds (14.88 M allocations: 961.978 MB, 8.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   1.278456 seconds (9.94 M allocations: 699.483 MB, 7.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.537770 seconds (13.68 M allocations: 897.916 MB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   1.388384 seconds (7.34 M allocations: 561.335 MB, 5.35% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.727356 seconds (4.84 M allocations: 428.519 MB, 8.23% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   4.227977 seconds (32.15 M allocations: 2.236 GB, 6.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   4.062453 seconds (36.74 M allocations: 2.459 GB, 8.23% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   3.571258 seconds (24.51 M allocations: 1.864 GB, 7.02% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   4.667012 seconds (36.05 M allocations: 2.425 GB, 7.14% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   4.548922 seconds (21.28 M allocations: 1.707 GB, 4.60% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   2.945871 seconds (13.85 M allocations: 1.347 GB, 5.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.746471 seconds (7.75 M allocations: 1.052 GB, 6.44% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   9.980266 seconds (52.92 M allocations: 5.243 GB, 7.96% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   9.153785 seconds (47.09 M allocations: 4.963 GB, 7.66% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#  10.399204 seconds (70.61 M allocations: 6.096 GB, 9.72% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   9.347555 seconds (47.09 M allocations: 4.963 GB, 7.55% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#  12.049737 seconds (67.92 M allocations: 5.967 GB, 6.94% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   9.710220 seconds (34.41 M allocations: 4.353 GB, 6.27% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   6.913359 seconds (17.18 M allocations: 3.524 GB, 7.42% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  30.214408 seconds (158.42 M allocations: 18.403 GB, 7.64% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  30.522233 seconds (147.65 M allocations: 17.886 GB, 8.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  33.569662 seconds (221.45 M allocations: 21.441 GB, 8.86% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  29.665950 seconds (147.65 M allocations: 17.886 GB, 7.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  29.557891 seconds (147.65 M allocations: 17.886 GB, 7.74% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  30.039676 seconds (147.65 M allocations: 17.886 GB, 7.79% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  29.277826 seconds (147.65 M allocations: 17.886 GB, 7.77% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  29.509784 seconds (106.82 M allocations: 15.925 GB, 6.37% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 166.811821 seconds (1.05 G allocations: 93.739 GB, 16.04% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 157.296353 seconds (1.02 G allocations: 91.928 GB, 16.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 146.353628 seconds (1.02 G allocations: 91.928 GB, 16.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 146.750849 seconds (1.02 G allocations: 91.928 GB, 16.28% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 174.970128 seconds (1.01 G allocations: 91.621 GB, 13.50% gc time)
# 1197.568484 seconds (7.52 G allocations: 674.132 GB, 12.79% gc time)
# α0[i] = [0,2,2]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.440422 seconds (33.60 M allocations: 1.866 GB, 12.94% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.974650 seconds (6.64 M allocations: 468.019 MB, 7.02% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.007112 seconds (9.94 M allocations: 642.855 MB, 8.79% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.899314 seconds (6.64 M allocations: 468.019 MB, 8.09% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.019871 seconds (9.09 M allocations: 597.550 MB, 7.92% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.911579 seconds (4.85 M allocations: 372.853 MB, 5.64% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.477387 seconds (3.17 M allocations: 283.837 MB, 7.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.681466 seconds (20.77 M allocations: 1.464 GB, 7.70% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.534981 seconds (23.83 M allocations: 1.613 GB, 8.75% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.593790 seconds (15.90 M allocations: 1.227 GB, 11.22% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   3.118296 seconds (23.39 M allocations: 1.591 GB, 6.65% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   3.057101 seconds (13.79 M allocations: 1.125 GB, 5.08% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.902560 seconds (8.96 M allocations: 911.260 MB, 6.56% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.119521 seconds (5.01 M allocations: 715.650 MB, 8.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   5.867633 seconds (34.10 M allocations: 3.459 GB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.504488 seconds (30.02 M allocations: 3.263 GB, 7.81% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.122183 seconds (45.00 M allocations: 3.985 GB, 8.73% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.774300 seconds (30.02 M allocations: 3.263 GB, 7.87% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.935892 seconds (43.32 M allocations: 3.905 GB, 8.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   5.949920 seconds (21.95 M allocations: 2.875 GB, 6.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.098519 seconds (10.94 M allocations: 2.345 GB, 7.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  17.842735 seconds (100.53 M allocations: 12.106 GB, 7.66% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  17.243892 seconds (93.33 M allocations: 11.760 GB, 7.42% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  18.778291 seconds (139.98 M allocations: 14.008 GB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  17.145520 seconds (93.33 M allocations: 11.760 GB, 7.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  17.056524 seconds (93.33 M allocations: 11.760 GB, 7.00% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  17.159687 seconds (93.33 M allocations: 11.760 GB, 7.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  17.165368 seconds (93.33 M allocations: 11.760 GB, 6.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  17.803819 seconds (67.53 M allocations: 10.521 GB, 6.36% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
#  99.761784 seconds (665.32 M allocations: 61.062 GB, 19.56% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 110.184669 seconds (639.48 M allocations: 59.821 GB, 19.82% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 101.981356 seconds (639.48 M allocations: 59.821 GB, 19.43% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 100.174268 seconds (639.48 M allocations: 59.821 GB, 19.40% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 119.101465 seconds (635.90 M allocations: 59.649 GB, 16.29% gc time)
# 770.607390 seconds (4.76 G allocations: 439.968 GB, 15.17% gc time)
# α0[i] = [3,1,0]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.189566 seconds (33.60 M allocations: 1.866 GB, 14.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.847713 seconds (6.82 M allocations: 477.629 MB, 7.72% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.003170 seconds (10.21 M allocations: 657.269 MB, 9.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.818701 seconds (6.82 M allocations: 477.629 MB, 7.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   0.982629 seconds (9.41 M allocations: 614.766 MB, 8.40% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.906238 seconds (5.06 M allocations: 384.025 MB, 5.95% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.464098 seconds (3.29 M allocations: 290.033 MB, 8.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.564637 seconds (21.18 M allocations: 1.484 GB, 8.51% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.519338 seconds (23.92 M allocations: 1.617 GB, 12.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.115128 seconds (15.96 M allocations: 1.230 GB, 7.69% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   2.898594 seconds (23.51 M allocations: 1.597 GB, 7.28% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.809631 seconds (13.83 M allocations: 1.126 GB, 5.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.822612 seconds (8.93 M allocations: 909.469 MB, 6.45% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.143409 seconds (4.98 M allocations: 713.718 MB, 8.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   5.820792 seconds (34.03 M allocations: 3.455 GB, 7.97% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.681973 seconds (30.16 M allocations: 3.269 GB, 7.81% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.234255 seconds (45.22 M allocations: 3.994 GB, 8.67% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.605883 seconds (30.16 M allocations: 3.269 GB, 7.85% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.462744 seconds (43.52 M allocations: 3.913 GB, 8.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   5.955372 seconds (22.08 M allocations: 2.880 GB, 6.22% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.166703 seconds (11.08 M allocations: 2.351 GB, 7.37% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  18.124050 seconds (102.66 M allocations: 12.208 GB, 7.71% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  17.257623 seconds (95.67 M allocations: 11.872 GB, 6.98% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  19.347802 seconds (143.48 M allocations: 14.176 GB, 8.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  17.408796 seconds (95.67 M allocations: 11.872 GB, 7.52% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  17.465628 seconds (95.67 M allocations: 11.872 GB, 7.02% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  17.601755 seconds (95.67 M allocations: 11.872 GB, 7.57% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  17.625969 seconds (95.66 M allocations: 11.872 GB, 7.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  19.610997 seconds (69.47 M allocations: 10.614 GB, 6.36% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 105.035545 seconds (690.07 M allocations: 62.251 GB, 18.90% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 100.074844 seconds (664.92 M allocations: 61.043 GB, 19.17% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
#  99.555072 seconds (664.92 M allocations: 61.043 GB, 19.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 100.061604 seconds (664.92 M allocations: 61.043 GB, 19.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 130.547899 seconds (661.02 M allocations: 60.855 GB, 16.06% gc time)
# 781.236850 seconds (4.92 G allocations: 447.348 GB, 14.84% gc time)
# α0[i] = [2,1,1]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   5.103317 seconds (50.39 M allocations: 2.796 GB, 12.02% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   1.439768 seconds (9.94 M allocations: 699.483 MB, 6.98% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.470151 seconds (14.88 M allocations: 961.978 MB, 8.85% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   1.249909 seconds (9.94 M allocations: 699.483 MB, 7.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.498594 seconds (13.70 M allocations: 898.924 MB, 7.89% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   1.325343 seconds (7.35 M allocations: 562.126 MB, 5.33% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.711741 seconds (4.84 M allocations: 428.535 MB, 8.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   3.924849 seconds (32.07 M allocations: 2.232 GB, 7.62% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   3.846325 seconds (36.62 M allocations: 2.453 GB, 8.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   3.226582 seconds (24.43 M allocations: 1.860 GB, 7.38% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   4.550101 seconds (35.96 M allocations: 2.421 GB, 6.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   4.705421 seconds (21.22 M allocations: 1.705 GB, 4.15% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   3.225450 seconds (13.77 M allocations: 1.343 GB, 5.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.767849 seconds (7.67 M allocations: 1.048 GB, 5.78% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   9.361634 seconds (52.39 M allocations: 5.217 GB, 7.88% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   9.872833 seconds (46.56 M allocations: 4.937 GB, 7.68% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#  12.280754 seconds (69.82 M allocations: 6.058 GB, 10.13% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   9.363730 seconds (46.56 M allocations: 4.937 GB, 7.22% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#  12.100129 seconds (67.17 M allocations: 5.930 GB, 6.74% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   9.983166 seconds (34.09 M allocations: 4.337 GB, 6.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   6.907402 seconds (17.12 M allocations: 3.521 GB, 7.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  31.158457 seconds (159.00 M allocations: 18.431 GB, 7.75% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  32.315875 seconds (148.25 M allocations: 17.915 GB, 8.14% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  34.342015 seconds (222.35 M allocations: 21.485 GB, 8.72% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  29.306817 seconds (148.25 M allocations: 17.915 GB, 7.70% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  30.640204 seconds (148.25 M allocations: 17.915 GB, 8.04% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  29.451173 seconds (148.25 M allocations: 17.915 GB, 7.84% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  28.169533 seconds (148.25 M allocations: 17.915 GB, 8.11% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  30.424179 seconds (107.54 M allocations: 15.960 GB, 6.66% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 167.133948 seconds (1.07 G allocations: 94.375 GB, 16.03% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 151.106432 seconds (1.03 G allocations: 92.551 GB, 16.16% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 158.154621 seconds (1.03 G allocations: 92.551 GB, 16.19% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 158.715345 seconds (1.03 G allocations: 92.551 GB, 16.12% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 192.257313 seconds (1.02 G allocations: 92.258 GB, 13.35% gc time)
# 1240.290499 seconds (7.60 G allocations: 677.455 GB, 12.79% gc time)
# α0[i] = [1,1,2]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   6.213543 seconds (50.39 M allocations: 2.796 GB, 10.75% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   1.246773 seconds (9.94 M allocations: 699.483 MB, 7.74% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.542577 seconds (14.88 M allocations: 961.978 MB, 8.18% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   1.345981 seconds (9.94 M allocations: 699.483 MB, 7.61% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.567666 seconds (13.67 M allocations: 897.659 MB, 8.15% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   1.341030 seconds (7.33 M allocations: 561.016 MB, 5.84% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.730385 seconds (4.80 M allocations: 426.783 MB, 8.44% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   5.117751 seconds (31.65 M allocations: 2.212 GB, 6.51% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   4.292328 seconds (36.10 M allocations: 2.428 GB, 8.10% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   3.445293 seconds (24.09 M allocations: 1.843 GB, 7.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   4.339623 seconds (35.47 M allocations: 2.397 GB, 7.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   4.297949 seconds (20.94 M allocations: 1.691 GB, 4.56% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   2.816060 seconds (13.58 M allocations: 1.334 GB, 5.61% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.650472 seconds (7.56 M allocations: 1.042 GB, 7.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#  10.085162 seconds (51.47 M allocations: 5.173 GB, 8.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   9.812609 seconds (45.70 M allocations: 4.895 GB, 7.68% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   9.669132 seconds (68.52 M allocations: 5.996 GB, 8.61% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   8.459695 seconds (45.70 M allocations: 4.895 GB, 7.71% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#  14.613962 seconds (65.93 M allocations: 5.871 GB, 7.10% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   9.793403 seconds (33.44 M allocations: 4.306 GB, 6.13% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   7.261484 seconds (16.76 M allocations: 3.504 GB, 6.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  31.171188 seconds (155.37 M allocations: 18.257 GB, 7.67% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  28.849835 seconds (144.89 M allocations: 17.753 GB, 8.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  30.493156 seconds (217.30 M allocations: 21.242 GB, 8.79% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  27.745719 seconds (144.89 M allocations: 17.753 GB, 7.40% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  27.022921 seconds (144.89 M allocations: 17.753 GB, 7.84% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  25.921887 seconds (144.89 M allocations: 17.753 GB, 7.45% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  28.133010 seconds (144.88 M allocations: 17.753 GB, 7.86% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  28.143116 seconds (105.18 M allocations: 15.846 GB, 6.27% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 159.283899 seconds (1.04 G allocations: 93.334 GB, 16.14% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 166.176494 seconds (1.01 G allocations: 91.553 GB, 16.19% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 158.830899 seconds (1.01 G allocations: 91.553 GB, 16.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 150.652489 seconds (1.01 G allocations: 91.553 GB, 16.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 172.379349 seconds (1.00 G allocations: 91.266 GB, 13.59% gc time)
# 1200.672398 seconds (7.44 G allocations: 670.423 GB, 12.88% gc time)
# α0[i] = [0,1,3]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   2.854486 seconds (33.60 M allocations: 1.866 GB, 8.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.779715 seconds (6.64 M allocations: 468.019 MB, 8.13% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   0.909309 seconds (9.94 M allocations: 642.855 MB, 9.18% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.772999 seconds (6.64 M allocations: 468.019 MB, 7.86% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   0.946892 seconds (9.08 M allocations: 597.348 MB, 8.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.822134 seconds (4.84 M allocations: 372.472 MB, 6.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.437920 seconds (3.13 M allocations: 281.810 MB, 9.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.339611 seconds (20.20 M allocations: 1.436 GB, 8.41% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.281619 seconds (23.14 M allocations: 1.579 GB, 9.25% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.011325 seconds (15.44 M allocations: 1.204 GB, 8.34% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   2.696885 seconds (22.72 M allocations: 1.558 GB, 7.61% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.602302 seconds (13.37 M allocations: 1.104 GB, 5.50% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.693046 seconds (8.62 M allocations: 894.415 MB, 6.73% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.048902 seconds (4.78 M allocations: 703.980 MB, 9.01% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   6.367468 seconds (32.50 M allocations: 3.382 GB, 9.08% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.637919 seconds (28.58 M allocations: 3.193 GB, 7.72% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   5.817381 seconds (42.84 M allocations: 3.881 GB, 8.37% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.370607 seconds (28.58 M allocations: 3.193 GB, 7.63% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.005651 seconds (41.20 M allocations: 3.803 GB, 6.93% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   5.666844 seconds (20.86 M allocations: 2.822 GB, 6.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.076550 seconds (10.44 M allocations: 2.321 GB, 9.58% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  17.505401 seconds (96.91 M allocations: 11.932 GB, 7.77% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  17.216709 seconds (90.17 M allocations: 11.608 GB, 7.08% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  21.319792 seconds (135.22 M allocations: 13.780 GB, 8.01% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  17.733240 seconds (90.17 M allocations: 11.608 GB, 7.52% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  18.926592 seconds (135.22 M allocations: 13.780 GB, 8.01% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  17.439752 seconds (90.17 M allocations: 11.608 GB, 7.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  16.938763 seconds (90.16 M allocations: 11.608 GB, 7.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  18.767927 seconds (85.87 M allocations: 11.410 GB, 6.88% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
#  99.251211 seconds (650.80 M allocations: 60.365 GB, 19.50% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 100.882393 seconds (626.10 M allocations: 59.179 GB, 20.02% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 110.385333 seconds (939.12 M allocations: 74.240 GB, 19.57% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
#  96.440853 seconds (626.10 M allocations: 59.179 GB, 19.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 116.466341 seconds (622.73 M allocations: 59.017 GB, 16.88% gc time)
# 762.940738 seconds (5.02 G allocations: 452.816 GB, 15.39% gc time)
# α0[i] = [3,0,1]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.157952 seconds (33.60 M allocations: 1.866 GB, 14.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.784522 seconds (6.44 M allocations: 459.378 MB, 7.86% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   0.918743 seconds (9.64 M allocations: 629.893 MB, 9.03% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.786935 seconds (6.44 M allocations: 459.378 MB, 8.06% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   0.958210 seconds (8.90 M allocations: 590.355 MB, 8.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.837712 seconds (4.80 M allocations: 371.814 MB, 6.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.449359 seconds (3.16 M allocations: 284.671 MB, 8.87% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.505172 seconds (21.03 M allocations: 1.475 GB, 8.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.496053 seconds (24.17 M allocations: 1.627 GB, 12.81% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.076400 seconds (16.13 M allocations: 1.237 GB, 7.91% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   2.814002 seconds (23.72 M allocations: 1.605 GB, 7.43% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.755810 seconds (13.97 M allocations: 1.132 GB, 5.40% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.800983 seconds (9.02 M allocations: 913.429 MB, 7.06% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.069028 seconds (4.97 M allocations: 713.175 MB, 8.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   5.771037 seconds (33.54 M allocations: 3.431 GB, 7.94% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.658721 seconds (30.01 M allocations: 3.262 GB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.272610 seconds (44.99 M allocations: 3.984 GB, 8.73% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.580336 seconds (30.01 M allocations: 3.262 GB, 7.86% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.838218 seconds (43.29 M allocations: 3.902 GB, 8.03% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   6.026182 seconds (21.88 M allocations: 2.871 GB, 6.23% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.478150 seconds (13.99 M allocations: 2.494 GB, 7.63% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  20.081767 seconds (100.01 M allocations: 12.081 GB, 7.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  19.345714 seconds (93.10 M allocations: 11.749 GB, 6.92% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  20.872448 seconds (139.63 M allocations: 13.991 GB, 8.16% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  18.313624 seconds (93.10 M allocations: 11.749 GB, 7.45% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  17.826651 seconds (93.10 M allocations: 11.749 GB, 6.99% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  19.274571 seconds (93.10 M allocations: 11.749 GB, 7.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  18.581400 seconds (93.09 M allocations: 11.749 GB, 7.24% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  20.111207 seconds (88.34 M allocations: 11.528 GB, 6.92% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 107.630353 seconds (667.15 M allocations: 61.150 GB, 19.33% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 107.263279 seconds (643.80 M allocations: 60.028 GB, 19.70% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 108.296927 seconds (643.80 M allocations: 60.028 GB, 19.75% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
#  98.519593 seconds (643.80 M allocations: 60.028 GB, 19.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 119.579394 seconds (640.20 M allocations: 59.856 GB, 16.33% gc time)
# 795.182936 seconds (4.80 G allocations: 441.936 GB, 15.11% gc time)
# α0[i] = [2,0,2]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.494009 seconds (33.60 M allocations: 1.866 GB, 12.82% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.862946 seconds (6.44 M allocations: 459.378 MB, 7.58% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.037045 seconds (9.64 M allocations: 629.893 MB, 8.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.834199 seconds (6.44 M allocations: 459.378 MB, 7.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.001814 seconds (8.89 M allocations: 589.880 MB, 8.35% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.882841 seconds (4.80 M allocations: 371.596 MB, 5.69% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.477374 seconds (3.16 M allocations: 284.535 MB, 8.22% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.574898 seconds (20.99 M allocations: 1.473 GB, 8.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.604780 seconds (24.09 M allocations: 1.623 GB, 12.55% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.165202 seconds (16.08 M allocations: 1.234 GB, 7.70% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   2.913208 seconds (23.65 M allocations: 1.602 GB, 7.34% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.878119 seconds (13.94 M allocations: 1.130 GB, 5.12% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.892859 seconds (9.01 M allocations: 912.970 MB, 6.44% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.125101 seconds (4.98 M allocations: 713.507 MB, 7.85% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   5.862962 seconds (33.64 M allocations: 3.436 GB, 7.89% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.584525 seconds (30.04 M allocations: 3.263 GB, 7.80% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.164821 seconds (45.03 M allocations: 3.986 GB, 8.62% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.572853 seconds (30.04 M allocations: 3.263 GB, 7.76% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.432148 seconds (43.34 M allocations: 3.904 GB, 8.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   5.920700 seconds (21.91 M allocations: 2.872 GB, 6.20% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.097973 seconds (10.90 M allocations: 2.343 GB, 7.26% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  17.987934 seconds (100.38 M allocations: 12.099 GB, 7.71% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  17.197809 seconds (93.40 M allocations: 11.764 GB, 7.03% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  19.215230 seconds (140.08 M allocations: 14.013 GB, 8.32% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  17.323674 seconds (93.40 M allocations: 11.764 GB, 7.51% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  17.256606 seconds (93.40 M allocations: 11.764 GB, 7.09% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  17.273554 seconds (93.40 M allocations: 11.764 GB, 7.56% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  17.296859 seconds (93.40 M allocations: 11.763 GB, 7.06% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  17.938915 seconds (67.75 M allocations: 10.532 GB, 6.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 105.181783 seconds (671.53 M allocations: 61.360 GB, 18.96% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 110.922054 seconds (648.12 M allocations: 60.236 GB, 19.68% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 101.886199 seconds (648.12 M allocations: 60.236 GB, 19.51% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 103.435903 seconds (648.12 M allocations: 60.236 GB, 19.46% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 128.600588 seconds (644.52 M allocations: 60.063 GB, 16.64% gc time)
# 790.908086 seconds (4.80 G allocations: 441.985 GB, 15.20% gc time)
# α0[i] = [1,0,3]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   3.469328 seconds (33.60 M allocations: 1.866 GB, 13.15% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   0.811958 seconds (6.44 M allocations: 459.378 MB, 7.23% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   0.937560 seconds (9.64 M allocations: 629.893 MB, 8.47% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   0.804248 seconds (6.44 M allocations: 459.378 MB, 7.44% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   0.982330 seconds (8.88 M allocations: 589.065 MB, 8.38% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   0.876581 seconds (4.78 M allocations: 370.640 MB, 5.56% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.482903 seconds (3.12 M allocations: 282.264 MB, 7.40% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   2.642831 seconds (20.41 M allocations: 1.445 GB, 8.03% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   2.547139 seconds (23.39 M allocations: 1.589 GB, 8.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   2.350226 seconds (15.61 M allocations: 1.211 GB, 11.57% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   2.900623 seconds (22.95 M allocations: 1.568 GB, 7.30% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   2.858715 seconds (13.50 M allocations: 1.109 GB, 5.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   1.825012 seconds (8.69 M allocations: 897.136 MB, 6.39% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.140905 seconds (4.78 M allocations: 703.535 MB, 8.63% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   5.757731 seconds (32.22 M allocations: 3.368 GB, 8.01% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   5.369749 seconds (28.77 M allocations: 3.202 GB, 7.83% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   6.042268 seconds (43.12 M allocations: 3.894 GB, 8.71% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   5.725279 seconds (28.77 M allocations: 3.202 GB, 7.88% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#   7.421171 seconds (41.46 M allocations: 3.814 GB, 8.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   6.376108 seconds (20.95 M allocations: 2.826 GB, 6.36% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   4.500704 seconds (10.43 M allocations: 2.320 GB, 7.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  18.721619 seconds (96.38 M allocations: 11.906 GB, 7.72% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  19.000092 seconds (89.76 M allocations: 11.589 GB, 6.85% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  20.568100 seconds (134.62 M allocations: 13.751 GB, 8.18% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  17.975439 seconds (89.76 M allocations: 11.589 GB, 7.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  18.526851 seconds (89.76 M allocations: 11.589 GB, 7.14% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  18.398675 seconds (89.76 M allocations: 11.589 GB, 7.60% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  16.928331 seconds (89.75 M allocations: 11.588 GB, 7.05% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  18.350885 seconds (65.24 M allocations: 10.411 GB, 6.54% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 124.034432 seconds (649.53 M allocations: 60.304 GB, 20.01% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
#  99.210252 seconds (627.29 M allocations: 59.236 GB, 19.87% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
#  99.415075 seconds (627.29 M allocations: 59.236 GB, 19.63% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 100.159301 seconds (627.29 M allocations: 59.236 GB, 19.57% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 118.504666 seconds (623.67 M allocations: 59.062 GB, 16.48% gc time)
# 794.987234 seconds (4.64 G allocations: 434.606 GB, 15.21% gc time)
# α0[i] = [1,1,1]
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,1.0,250,0.0)
#   4.420890 seconds (50.39 M allocations: 2.796 GB, 11.89% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.1,250,0.0)
#   1.261621 seconds (9.94 M allocations: 699.483 MB, 8.10% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.01,250,0.0)
#   1.376329 seconds (14.88 M allocations: 961.978 MB, 9.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.005,250,0.0)
#   1.239370 seconds (9.94 M allocations: 699.483 MB, 7.74% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.001,250,0.0)
#   1.396876 seconds (13.68 M allocations: 898.192 MB, 8.74% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0005,250,0.0)
#   1.289010 seconds (7.35 M allocations: 561.647 MB, 6.48% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (4,0.0001,250,0.0)
#   0.658714 seconds (4.83 M allocations: 428.397 MB, 9.76% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.005,250,0.0)
#   3.826156 seconds (32.06 M allocations: 2.232 GB, 10.43% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.001,250,0.0)
#   3.658808 seconds (36.61 M allocations: 2.452 GB, 8.49% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0005,250,0.0)
#   3.232905 seconds (24.43 M allocations: 1.860 GB, 7.71% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,0.0001,250,0.0)
#   4.414137 seconds (35.94 M allocations: 2.420 GB, 7.24% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,7.0e-5,250,0.0)
#   4.430702 seconds (21.23 M allocations: 1.705 GB, 4.21% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,3.0e-5,250,0.0)
#   2.795096 seconds (13.81 M allocations: 1.345 GB, 4.93% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (3,1.0e-5,250,0.0)
#   1.715810 seconds (7.71 M allocations: 1.050 GB, 6.08% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.001,250,0.0)
#   9.357312 seconds (52.61 M allocations: 5.228 GB, 7.78% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0005,250,0.0)
#   8.676277 seconds (46.76 M allocations: 4.946 GB, 7.76% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,0.0001,250,0.0)
#   9.824087 seconds (70.11 M allocations: 6.072 GB, 9.45% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-5,250,0.0)
#   8.528467 seconds (46.76 M allocations: 4.946 GB, 7.69% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,1.0e-5,250,0.0)
#  11.515670 seconds (67.48 M allocations: 5.946 GB, 6.99% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,5.0e-6,250,0.0)
#   9.774960 seconds (34.25 M allocations: 4.345 GB, 6.11% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (2,2.0e-6,250,0.0)
#   6.889441 seconds (17.18 M allocations: 3.524 GB, 8.44% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.001,250,0.0)
#  28.989706 seconds (159.37 M allocations: 18.449 GB, 7.71% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0005,250,0.0)
#  27.438824 seconds (148.56 M allocations: 17.930 GB, 7.60% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,0.0001,250,0.0)
#  31.434983 seconds (222.81 M allocations: 21.507 GB, 8.53% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,5.0e-5,250,0.0)
#  28.099246 seconds (148.56 M allocations: 17.930 GB, 7.73% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,1.0e-5,250,0.0)
#  27.510893 seconds (148.56 M allocations: 17.930 GB, 7.79% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,6.0e-6,250,0.0)
#  26.685994 seconds (148.56 M allocations: 17.930 GB, 7.44% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,3.0e-6,250,0.0)
#  28.423668 seconds (148.56 M allocations: 17.929 GB, 8.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (1,9.0e-7,250,0.0)
#  28.385084 seconds (107.64 M allocations: 15.964 GB, 6.31% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,0.0001,250,0.0)
# 171.158690 seconds (1.06 G allocations: 94.288 GB, 16.29% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-5,250,0.0)
# 156.706983 seconds (1.03 G allocations: 92.456 GB, 16.19% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-5,250,0.0)
# 147.361755 seconds (1.03 G allocations: 92.456 GB, 16.18% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,5.0e-6,250,0.0)
# 147.974586 seconds (1.03 G allocations: 92.456 GB, 16.07% gc time)
# (scales[k],epsvec[k],nitervec[k],tolvec[k]) = (0,1.0e-6,250,0.0)
# 180.508559 seconds (1.02 G allocations: 92.158 GB, 13.29% gc time)
# 1185.089230 seconds (7.59 G allocations: 677.160 GB, 12.88% gc time)

# %%
NN = map(Int,sqrt(size(h,1)))
bary = reshape(h,NN,NN);

# %%
g =[1/2;1/2]
pcolormesh(min(bary,6e-5),cmap="bone_r");axis("off")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x321b9af50>)
# (0.0,600.0,0.0,600.0)

# %%
h,s,u,ϵ, α, λ = Array{Float64}(1), 2, Inf, 1.,1., 1. 
baryKL!(h,s,u,ϵ,α,λ)
# Out:
# 1-element Array{Float64,1}:
#  NaN

# %%
(((s.^(ϵ/(ϵ+λ)).*exp(-!isinf(u).*u/(ϵ+λ))))*α).^((ϵ+λ)/ϵ)

# %%
-(!isinf(u).*u)
# Out:
# -0.0

# %%
nnz(K[1])/length(K[1])
#size(K[1])
# Out:
# 0.00014832821034360677

# %%
b=load("../output/barycenters/GHK2d_data/baryGHK310.jld")
B=b["bary"]
figure(figsize=(5.12, 5.12), dpi=100,frameon="false")

imshow(flipdim(min(B,4e-5),1),cmap="gray_r"); axis("off")
#savefig("../output/barycenters/m3.png")
savefig("../output/barycenters/baryGHK310.png", dpi=100)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3220d6910>)
